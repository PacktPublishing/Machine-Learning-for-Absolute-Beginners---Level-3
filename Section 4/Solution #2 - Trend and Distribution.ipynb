# %% [markdown]
# ## <b> Course: Machine Learning for Absolute Beginners - Level 3
# #### By: Idan Gabrieli
# #### <p style="color:DodgerBlue;">Exercise: 2 - Trend and Distribution Charts</p>
# *****************************

# %% [markdown]
# ### Step 1 - Line Chart and Area Chart

# %% [markdown]
# Import matplotlib, seaborn and pandas libraries.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Copy the provided csv file called "weatherAUS.csv" into your working directory is the JupyterLab tool (you can use the "upload files" option in the navigator bar on the left upper side).
# Use Pandas to load the csv file into a dataframe object called 'weatherAUS' with the parse_dates parameter. Print the first rows on the dataframe.

# %% [markdown]
# Syntax : weatherAUS = pd.read_csv('weatherAUS.csv', parse_dates=['Date'])

# %%
weatherAUS = pd.read_csv('weatherAUS.csv', parse_dates=['Date'])

# %%
weatherAUS.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 0           W           44.0          W  ...      8.0       NaN     16.9
# 1         WNW           44.0        NNW  ...      NaN       NaN     17.2
# 2         WSW           46.0          W  ...      NaN       2.0     21.0
# 3          NE           24.0         SE  ...      NaN       NaN     18.1
# 4           W           41.0        ENE  ...      7.0       8.0     17.8
#
#    Temp3pm  RainToday  RISK_MM  RainTomorrow  Year  Month  Day
# 0     21.8         No      0.0            No  2008     12    1
# 1     24.3         No      0.0            No  2008     12    2
# 2     23.2         No      0.0            No  2008     12    3
# 3     26.5         No      1.0            No  2008     12    4
# 4     29.7         No      0.2            No  2008     12    5
#
# [5 rows x 27 columns]

# %% [markdown]
# Print the shape of the dataframe.

# %%
weatherAUS.shape
# Out:
# (142193, 27)

# %% [markdown]
# Print detailed information about the columns of the dataframe using the info() function.

# %%
weatherAUS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 27 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  datetime64[ns]
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
#  17  Cloud9am       88536 non-null   float64
#  18  Cloud3pm       85099 non-null   float64
#  19  Temp9am        141289 non-null  float64
#  20  Temp3pm        139467 non-null  float64
#  21  RainToday      140787 non-null  object
#  22  RISK_MM        142193 non-null  float64
#  23  RainTomorrow   142193 non-null  object
#  24  Year           142193 non-null  int64
#  25  Month          142193 non-null  int64
#  26  Day            142193 non-null  int64
# dtypes: datetime64[ns](1), float64(17), int64(3), object(6)
# memory usage: 29.3+ MB

# %% [markdown]
# Run the following lines in order to parse the 'Date' column into 'year', 'month', 'day columns:
#
# weatherAUS['Year']=weatherAUS['Date'].dt.year
#
# weatherAUS['Month']=weatherAUS['Date'].dt.month
#
# weatherAUS['Day']=weatherAUS['Date'].dt.day
#
# weatherAUS.head()

# %%
weatherAUS['Year']=weatherAUS['Date'].dt.year
weatherAUS['Month']=weatherAUS['Date'].dt.month
weatherAUS['Day']=weatherAUS['Date'].dt.day

weatherAUS.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 0           W           44.0          W  ...      8.0       NaN     16.9
# 1         WNW           44.0        NNW  ...      NaN       NaN     17.2
# 2         WSW           46.0          W  ...      NaN       2.0     21.0
# 3          NE           24.0         SE  ...      NaN       NaN     18.1
# 4           W           41.0        ENE  ...      7.0       8.0     17.8
#
#    Temp3pm  RainToday  RISK_MM  RainTomorrow  Year  Month  Day
# 0     21.8         No      0.0            No  2008     12    1
# 1     24.3         No      0.0            No  2008     12    2
# 2     23.2         No      0.0            No  2008     12    3
# 3     26.5         No      1.0            No  2008     12    4
# 4     29.7         No      0.2            No  2008     12    5
#
# [5 rows x 27 columns]

# %% [markdown]
# Create a new dataframe called "df1" while filtering the rows using the following conditions:
#
# 'Location'=='Albury'
#
# 'Year'==2008
#
# 'Month']==12

# %%
con1=weatherAUS['Location']=='Albury'
con2=weatherAUS['Year']==2008
con3=weatherAUS['Month']==12
df1=weatherAUS[con1 & con2 & con3]
df1.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 0           W           44.0          W  ...      8.0       NaN     16.9
# 1         WNW           44.0        NNW  ...      NaN       NaN     17.2
# 2         WSW           46.0          W  ...      NaN       2.0     21.0
# 3          NE           24.0         SE  ...      NaN       NaN     18.1
# 4           W           41.0        ENE  ...      7.0       8.0     17.8
#
#    Temp3pm  RainToday  RISK_MM  RainTomorrow  Year  Month  Day
# 0     21.8         No      0.0            No  2008     12    1
# 1     24.3         No      0.0            No  2008     12    2
# 2     23.2         No      0.0            No  2008     12    3
# 3     26.5         No      1.0            No  2008     12    4
# 4     29.7         No      0.2            No  2008     12    5
#
# [5 rows x 27 columns]

# %% [markdown]
# Create a new dataframe called "df2" while filtering the rows using the following conditions:
#
# 'Location'=='Albury'
#
# 'Year'==2009
#
# 'Month']==1

# %%
con1=weatherAUS['Location']=='Albury'
con2=weatherAUS['Year']==2009
con3=weatherAUS['Month']==1
df2=weatherAUS[con1 & con2 & con3]
df2.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 30 2009-01-01   Albury     11.3     26.5       0.0          NaN       NaN
# 31 2009-01-02   Albury      9.6     23.9       0.0          NaN       NaN
# 32 2009-01-03   Albury     10.5     28.8       0.0          NaN       NaN
# 33 2009-01-04   Albury     12.3     34.6       0.0          NaN       NaN
# 34 2009-01-05   Albury     12.9     35.8       0.0          NaN       NaN
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 30         WNW           56.0          W  ...      NaN       NaN     19.7
# 31           W           41.0        WSW  ...      NaN       NaN     14.9
# 32         SSE           26.0        SSE  ...      NaN       NaN     17.1
# 33         WNW           37.0        SSE  ...      NaN       NaN     20.7
# 34         WNW           41.0        ENE  ...      NaN       NaN     22.4
#
#     Temp3pm  RainToday  RISK_MM  RainTomorrow  Year  Month  Day
# 30     25.7         No      0.0            No  2009      1    1
# 31     22.1         No      0.0            No  2009      1    2
# 32     26.5         No      0.0            No  2009      1    3
# 33     33.9         No      0.0            No  2009      1    4
# 34     34.4         No      0.0            No  2009      1    5
#
# [5 rows x 27 columns]

# %% [markdown]
# Create two lines on the same chart. One line with the data in "df1" and the second line with the data in the "df2" . The X-axis will be the 'Day' and the Y-axis will be 'MinTemp'.

# %%
fig, ax = plt.subplots(figsize=(10,5))  
ax.plot('Day', 'MinTemp', label='12-2008', color='red', linestyle=':', linewidth=1, marker='o', data=df1) 
ax.plot('Day', 'MinTemp', label='01-2009', color='blue', linestyle=':', linewidth=1, marker='o', data=df2) 

ax.set_xlabel('Day')  
ax.set_ylabel('MinTemp') 
ax.set_title("Albury MinTemp")
ax.set_xticks(df1.index)
ax.legend(loc='upper left') 
plt.show()

# %% [markdown]
# Create a new dataframe called "df3" while filtering the rows using the following conditions:
#
# 'Location'=='Albury'
#
# 'Year'==2009

# %%
con1=weatherAUS['Location']=='Albury'
con2=weatherAUS['Year']==2009
df3=weatherAUS[con1 & con2]
df3.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 30 2009-01-01   Albury     11.3     26.5       0.0          NaN       NaN
# 31 2009-01-02   Albury      9.6     23.9       0.0          NaN       NaN
# 32 2009-01-03   Albury     10.5     28.8       0.0          NaN       NaN
# 33 2009-01-04   Albury     12.3     34.6       0.0          NaN       NaN
# 34 2009-01-05   Albury     12.9     35.8       0.0          NaN       NaN
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 30         WNW           56.0          W  ...      NaN       NaN     19.7
# 31           W           41.0        WSW  ...      NaN       NaN     14.9
# 32         SSE           26.0        SSE  ...      NaN       NaN     17.1
# 33         WNW           37.0        SSE  ...      NaN       NaN     20.7
# 34         WNW           41.0        ENE  ...      NaN       NaN     22.4
#
#     Temp3pm  RainToday  RISK_MM  RainTomorrow  Year  Month  Day
# 30     25.7         No      0.0            No  2009      1    1
# 31     22.1         No      0.0            No  2009      1    2
# 32     26.5         No      0.0            No  2009      1    3
# 33     33.9         No      0.0            No  2009      1    4
# 34     34.4         No      0.0            No  2009      1    5
#
# [5 rows x 27 columns]

# %% [markdown]
# Aggregate all rows in "df3" using the 'Month' column while using the mean() aggregation function. Save the result in "df4".

# %%
df4=df3.groupby('Month').mean()
df4.head()
# Out:
#          MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Month
# 1      16.312903  34.658065  0.251613          NaN       NaN      42.677419
# 2      17.453571  33.425000  0.128571          NaN       NaN      42.730769
# 3      12.748387  28.322581  0.774194          NaN       NaN      36.483871
# 4       9.050000  21.770000  2.826667          NaN       NaN      34.266667
# 5       5.122581  18.309677  0.219355          NaN       NaN      23.677419
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Month
# 1         11.935484     18.548387    41.903226    17.870968  1013.064516
# 2          9.714286     14.185185    45.964286    21.500000  1012.942857
# 3          6.129032     15.483871    61.387097    31.806452  1017.119355
# 4          6.833333     13.100000    67.666667    41.300000  1019.796667
# 5          4.000000     11.193548    79.419355    49.387097  1024.454839
#
#        Pressure3pm  Cloud9am  Cloud3pm    Temp9am    Temp3pm   RISK_MM  \
# Month
# 1      1009.770968  4.000000     1.000  22.993548  32.964516  0.251613
# 2      1009.942857  5.500000     6.000  22.142857  31.796429  0.128571
# 3      1014.538710  6.000000     5.375  16.864516  26.735484  0.774194
# 4      1016.633333  7.083333     6.100  13.796667  20.933333  2.826667
# 5      1021.574194  6.900000     6.625   9.974194  17.774194  0.258065
#
#          Year   Day
# Month
# 1      2009.0  16.0
# 2      2009.0  14.5
# 3      2009.0  16.0
# 4      2009.0  15.5
# 5      2009.0  16.0

# %% [markdown]
# Create a line chart of the average MinTemp Per Month on 2009 is "Albury".

# %%
fig, ax = plt.subplots(figsize=(10,5))  
ax.plot(df4.index, 'MinTemp', color='red', linestyle=':', linewidth=1, marker='o', data=df4) 
ax.set_xlabel('Month')  
ax.set_ylabel('MinTemp') 
ax.set_title("Albury Average MinTemp Per Month on 2009")
ax.set_xticks(df4.index)
plt.show()

# %% [markdown]
# Create an area chart using the same data as the above line chart (tip - use the fill_between function).

# %%
fig, ax = plt.subplots(figsize=(10,5))  
ax.plot(df4.index, 'MinTemp', color='black', linestyle=':', linewidth=1, marker='o', data=df4)
ax.fill_between(df4.index, 'MinTemp', 0, color='red', alpha=0.4, data=df4)

ax.set_xlabel('Month')  
ax.set_ylabel('MinTemp') 
ax.set_title("Albury Average MinTemp Per Month on 2009")
ax.set_xticks(df4.index)
plt.show()

# %% [markdown]
# *****************************
# ### Step 2 - Histogram Chart

# %% [markdown]
# Load the "heart.csv" dataset. Print the first five rows. Every row represents the medical heart health details of one person.

# %%
heart = pd.read_csv('heart.csv')
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# Run the info() function on the dataframe. There are 1025 rows and there are no missing values.

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# Replace the columns names in the dataframe with the following labels:
#
#
# ['Age', 'Gender', 'ChestPain', 'RestingBloodPressure', 'Cholestrol', 'FastingBloodSugar', 'RestingECG', 'MaxHeartRateAchivied',
#        'ExerciseIndusedAngina', 'Oldpeak', 'Slope', 'MajorVessels', 'Thalassemia', 'Target']

# %%
heart.columns = ['Age', 'Gender', 'ChestPain', 'RestingBloodPressure', 'Cholestrol', 'FastingBloodSugar', 'RestingECG', 'MaxHeartRateAchivied',
       'ExerciseIndusedAngina', 'Oldpeak', 'Slope', 'MajorVessels', 'Thalassemia', 'Target']
heart.head()
# Out:
#    Age  Gender  ChestPain  RestingBloodPressure  Cholestrol  \
# 0   52       1          0                   125         212
# 1   53       1          0                   140         203
# 2   70       1          0                   145         174
# 3   61       1          0                   148         203
# 4   62       0          0                   138         294
#
#    FastingBloodSugar  RestingECG  MaxHeartRateAchivied  ExerciseIndusedAngina  \
# 0                  0           1                   168                      0
# 1                  1           0                   155                      1
# 2                  0           1                   125                      1
# 3                  0           1                   161                      0
# 4                  1           1                   106                      0
#
#    Oldpeak  Slope  MajorVessels  Thalassemia  Target
# 0      1.0      2             2            3       0
# 1      3.1      0             0            3       0
# 2      2.6      0             0            3       0
# 3      0.0      2             1            3       0
# 4      1.9      1             3            2       0

# %% [markdown]
# Print the number of unique entries in each column (tip - use the nunique function). Using this information we can identify categorical variables, such as: 'Gender', 'ChestPain' etc.

# %%
print('unique entries in each column')
heart.nunique()
# Out:
# unique entries in each column
# Age                       41
# Gender                     2
# ChestPain                  4
# RestingBloodPressure      49
# Cholestrol               152
# FastingBloodSugar          2
# RestingECG                 3
# MaxHeartRateAchivied      91
# ExerciseIndusedAngina      2
# Oldpeak                   40
# Slope                      3
# MajorVessels               5
# Thalassemia                4
# Target                     2
# dtype: int64

# %% [markdown]
# Using Matplotib, create a histogram chart with 5 bins for analyzing the distribution of the data in the "Age" column.

# %%
fig, ax = plt.subplots() 
ax.hist(heart['Age'], bins=5, edgecolor='black', color='green')
ax.set_xlabel('Ages')  
ax.set_ylabel('People') 
ax.set_title("Histogram Chart") 
plt.show()

# %% [markdown]
# Now change the bin to 10.

# %%
fig, ax = plt.subplots() 
ax.hist(heart['Age'], bins=10, edgecolor='black', color='red')
ax.set_xlabel('Ages')  
ax.set_ylabel('People') 
ax.set_title("Histogram Chart") 
plt.show()

# %% [markdown]
# *****************************
# ### Step 3 - Density Curve Chart

# %% [markdown]
# Using Seaborn, create a Density curve chart for analyzing the distribution of the "Age" column (tip - use the kdeplot function).

# %%
fig, ax = plt.subplots() 
sns.kdeplot(heart['Age'], shade=True, color="red",  ax=ax)
ax.set_ylabel('Density') 
ax.set_title('Density Chart') 
plt.show()

# %% [markdown]
# *****************************
# ### Step 4 - Box-and-Whisker Chart

# %% [markdown]
# Replace the numerical values in the "ChestPain" columns based on the following mapping:
#
# 0:'Typical Angina', 1:'Atypical Angina', 2:'Non-Anginal', 3:'Asymptomatic'
#
# (tip - create an empty list, use the map function to fill that list, convert the list of a Series object and store the result in the "ChestPain" column).

# %%
mapping=[]
mapping = heart['ChestPain'].map({0:'Typical Angina', 1:'Atypical Angina', 2:'Non-Anginal', 3:'Asymptomatic'})
heart['ChestPain']=pd.Series(mapping)
heart.head()
# Out:
#    Age  Gender       ChestPain  RestingBloodPressure  Cholestrol  \
# 0   52       1  Typical Angina                   125         212
# 1   53       1  Typical Angina                   140         203
# 2   70       1  Typical Angina                   145         174
# 3   61       1  Typical Angina                   148         203
# 4   62       0  Typical Angina                   138         294
#
#    FastingBloodSugar  RestingECG  MaxHeartRateAchivied  ExerciseIndusedAngina  \
# 0                  0           1                   168                      0
# 1                  1           0                   155                      1
# 2                  0           1                   125                      1
# 3                  0           1                   161                      0
# 4                  1           1                   106                      0
#
#    Oldpeak  Slope  MajorVessels  Thalassemia  Target
# 0      1.0      2             2            3       0
# 1      3.1      0             0            3       0
# 2      2.6      0             0            3       0
# 3      0.0      2             1            3       0
# 4      1.9      1             3            2       0

# %% [markdown]
# Using Seaborn, create a Box-and-Whisker chart. Use the "ChestPain" for the x-axis and "Age" for the y-axis. We will be able to see the distribution age of the four groups in the ChestPain column.

# %%
fig, ax = plt.subplots(figsize=(10,5)) 
sns.boxplot(x='ChestPain', y='Age', data=heart, ax=ax)
plt.show()

# %% [markdown]
# Create the same Box-and-Whisker chart but this time add the "Gender" as the second categorical variable (tip - use the "hue" parameter).

# %%
fig, ax = plt.subplots(figsize=(10,5)) 
sns.boxplot(x='ChestPain', y='Age', hue='Gender', data=heart, ax=ax)
plt.show()

# %% [markdown]
# Create a Box-and-Whisker chart with the x-axis as the "Gender" and "Cholestrol" for y-axis.

# %%
fig, ax = plt.subplots(figsize=(7,7)) 
sns.boxplot(x='Gender', y='Cholestrol', data=heart, ax=ax)
plt.show()

# %% [markdown]
# *****************************
# ### Step 5 - Violin Chart and Bee-swarm Chart

# %% [markdown]
# Using Seaborn, create a Violin chart. Use the "ChestPain" for the x-axis and "Age" for the y-axis.

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.violinplot(x='ChestPain', y='Age', data=heart, ax=ax)
plt.show()

# %% [markdown]
# Using Seaborn, create a Bee-Swarm chart. Use the "ChestPain" for the x-axis and "Age" for the y-axis.

# %%
fig, ax = plt.subplots(figsize=(10,5)) 
sns.swarmplot(x='ChestPain', y='Age', data=heart, ax=ax)
plt.show()

# %% [markdown]
# Add the "Gender" variable as colors in the Bee-Swarm chart.

# %%
fig, ax = plt.subplots(figsize=(10,5)) 
sns.swarmplot(x='ChestPain', y='Age', hue='Gender', data=heart, ax=ax)
plt.show()

# %% [markdown]
# Create a chart with a box plot and bee-swarm plot on the same chart using the "ChestPain" as x-axis and "Age" as y-axis.

# %%
fig, ax = plt.subplots(figsize=(10,7)) 
sns.boxplot(x='ChestPain', y='Age', data=heart, ax=ax)
sns.swarmplot(x='ChestPain', y='Age', data=heart, color='black', ax=ax)
plt.show()

# %% [markdown]
# ************************
# ### Congratulations!!! you completed exercise 2.
# ## End of document
# ************************
